# %% [markdown]
# # EECS 491 Final Project: Structure Learning

# %%
from graphviz import Graph, Digraph
import pgmpy
from pgmpy.models import BayesianModel
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
from pgmpy.sampling import GibbsSampling
from pgmpy.estimators import ExhaustiveSearch, HillClimbSearch, ConstraintBasedEstimator
from pgmpy.estimators import BDeuScore, K2Score, BicScore
import time

# %% [markdown]
# ## Overview

# %% [markdown]
# ## True Model
#
# For sampling and comparison purposes, we will be using the following model (Adpted from Barber Exercise 3.6) that describes the probability of a car starting given certain factors.

# %%
q5 = Digraph()
q5.node('b', 'Battery')
q5.node('g', 'Gauge')
q5.node('f', 'Fuel')
q5.node('t', 'Turns Over')
q5.node('s', 'Starts')
q5.edges(['bg','fg','bt','ts','fs'])
q5

# %%
# Create model from list of edges
model = BayesianModel([('B','G'),('F','G'),('B','T'),('T','S'),('F','S')])

# define p(B) and p(M) 
# variable_card is cardinality = 2 for true|false
# values are defined in numeric order p(x_i = [false, true]), ie  [0, 1]
priorB = TabularCPD(variable='B', variable_card=2, values=[[0.02, 0.98]])
priorF = TabularCPD(variable='F', variable_card=2, values=[[0.05, 0.95]])

# define p(G|B,F)
# Variables cycle in numerical order of evidence values,
# ie BF = 00, 01, 10, 11 for each value of G.
cpdG = TabularCPD(variable='G', variable_card=2, 
                  evidence=['B', 'F'], evidence_card=[2, 2],
                  values=[[0.99, 0.1, 0.97, 0.04], 
                          [0.01, 0.9, 0.03, 0.96]])

# define p(T|B)
cpdT = TabularCPD(variable='T', variable_card=2,
                 evidence=['B'], evidence_card=[2],
                 values=[[0.98, 0.03],
                         [0.02, 0.97]])

# define p(S|T,F)
cpdS = TabularCPD(variable='S', variable_card=2, 
                  evidence=['T', 'F'], evidence_card=[2, 2],
                  values=[[0.99, 1.0, 0.92, 0.01], 
                          [0.01, 0.0, 0.08, 0.99]])

# add probabilities to model
model.add_cpds(priorB, priorF, cpdG, cpdT, cpdS)
print(model.check_model())
inference = VariableElimination(model)
print(model.edges())
# Out:
# True
# [('B', 'G'), ('B', 'T'), ('F', 'G'), ('F', 'S'), ('T', 'S')]

# %%
# generate sets of samples
sampler = GibbsSampling(model)
sample10 = sampler.sample(size=10, return_type='dataframe')
sample100 = sampler.sample(size=100, return_type='dataframe')
sample1000 = sampler.sample(size=1000, return_type='dataframe')
sample10000 = sampler.sample(size=10000, return_type='dataframe')

bdeu10 = BDeuScore(sample10, equivalent_sample_size=10)
k210 = K2Score(sample10)
bic10 = BicScore(sample10)

bdeu100 = BDeuScore(sample100, equivalent_sample_size=100)
k2100 = K2Score(sample100)
bic100 = BicScore(sample100)

bdeu1000 = BDeuScore(sample1000, equivalent_sample_size=1000)
k21000 = K2Score(sample1000)
bic1000 = BicScore(sample1000)

bdeu10000 = BDeuScore(sample10000, equivalent_sample_size=10000)
k210000 = K2Score(sample10000)
bic10000 = BicScore(sample10000)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 1218.29it/s]
# 100%|██████████| 99/99 [00:00<00:00, 1443.09it/s]
# 100%|██████████| 999/999 [00:00<00:00, 1832.08it/s]
# 100%|██████████| 9999/9999 [00:04<00:00, 2309.24it/s]

# %% [markdown]
# ## Network Scoring
#
# ### Exhaustive Search

# %%
es = ExhaustiveSearch(sample2, scoring_method=bic2)
start = time.time()
best_model = es.estimate()
end = time.time()
print(best_model.edges())
print("Elapsed Time:")
print(end-start)

print("\nAll DAGs by score:")
for score, dag in reversed(es.all_scores()):
    print(score, dag.edges())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-caa70bf541fa> in <module>
#       1 es = ExhaustiveSearch(sample2, scoring_method=bic2)
# ----> 2 best_model = es.estimate()
#       3 print(best_model.edges())
#       4
#       5 print("\nAll DAGs by score:")
#
# ~/491_venv/lib/python3.7/site-packages/pgmpy/estimators/ExhaustiveSearch.py in estimate(self)
#     184         """
#     185
# --> 186         best_dag = max(self.all_dags(), key=self.scoring_method.score)
#     187
#     188         best_model = DAG()
#
# ~/491_venv/lib/python3.7/site-packages/pgmpy/estimators/ExhaustiveSearch.py in all_dags(self, nodes)
#     100             graph.add_nodes_from(nodes)
#     101             graph.add_edges_from(graph_edges)
# --> 102             if nx.is_directed_acyclic_graph(graph):
#     103                 yield graph
#     104
#
# ~/491_venv/lib/python3.7/site-packages/networkx/algorithms/dag.py in is_directed_acyclic_graph(G)
#     118         True if `G` is a DAG, False otherwise
#     119     """
# --> 120     return G.is_directed() and not has_cycle(G)
#     121
#     122
#
# ~/491_venv/lib/python3.7/site-packages/networkx/algorithms/dag.py in has_cycle(G)
#      98     """Decides whether the directed graph has a cycle."""
#      99     try:
# --> 100         consume(topological_sort(G))
#     101     except nx.NetworkXUnfeasible:
#     102         return True
#
# ~/491_venv/lib/python3.7/site-packages/networkx/utils/misc.py in consume(iterator)
#     274     "Consume the iterator entirely."
#     275     # Feed the entire iterator into a zero-length deque.
# --> 276     deque(iterator, maxlen=0)
#     277
#     278
#
# ~/491_venv/lib/python3.7/site-packages/networkx/algorithms/dag.py in topological_sort(G)
#     188             "Topological sort not defined on undirected graphs.")
#     189
# --> 190     indegree_map = {v: d for v, d in G.in_degree() if d > 0}
#     191     # These nodes have zero indegree and ready to be returned.
#     192     zero_indegree = [v for v, d in G.in_degree() if d == 0]
#
# ~/491_venv/lib/python3.7/site-packages/networkx/algorithms/dag.py in <dictcomp>(.0)
#     188             "Topological sort not defined on undirected graphs.")
#     189
# --> 190     indegree_map = {v: d for v, d in G.in_degree() if d > 0}
#     191     # These nodes have zero indegree and ready to be returned.
#     192     zero_indegree = [v for v, d in G.in_degree() if d == 0]
#
# ~/491_venv/lib/python3.7/site-packages/networkx/classes/reportviews.py in __iter__(self)
#     491         if weight is None:
#     492             for n in self._nodes:
# --> 493                 preds = self._pred[n]
#     494                 yield (n, len(preds))
#     495         else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Hill Climbing
#
# #### Compare \# samples

# %%
hc = HillClimbSearch(sample10, scoring_method=BicScore(sample10))
start = time.time()
best_model = hc.estimate()
end = time.time()
print(best_model.edges())
print('Elapsed Time:')
print(end-start)
# Out:
# []
# Elapsed Time:
# 0.2518739700317383

# %%
hc = HillClimbSearch(sample100, scoring_method=BicScore(sample100))
start = time.time()
best_model = hc.estimate()
end = time.time()
print(best_model.edges())
print('Elapsed Time:')
print(end-start)
# Out:
# [('B', 'T'), ('B', 'F'), ('F', 'G'), ('T', 'S')]
# Elapsed Time:
# 0.48983192443847656

# %%
hc = HillClimbSearch(sample10000, scoring_method=BicScore(sample10000))
start = time.time()
best_modelhc = hc.estimate()
end = time.time()
print(best_model.edges())
print('Elapsed Time:')
print(end-start)
# Out:
# [('B', 'T'), ('G', 'F'), ('G', 'B'), ('F', 'S'), ('T', 'S')]
# Elapsed Time:
# 0.5831873416900635

# %% [markdown]
# #### Compare across tabu length

# %%
hc = HillClimbSearch(sample10000, scoring_method=BicScore(sample10000))
start = time.time()
best_modelhc1 = hc.estimate(tabu_length=10)
end = time.time()
print(best_model.edges())
print('Elapsed Time:')
print(end-start)
# Out:
# [('B', 'T'), ('G', 'F'), ('G', 'B'), ('F', 'S'), ('T', 'S')]
# Elapsed Time:
# 0.5921285152435303

# %%
hc = HillClimbSearch(sample10000, scoring_method=BicScore(sample10000))
start = time.time()
best_modelhc2 = hc.estimate(tabu_length=100)
end = time.time()
print(best_model.edges())
print('Elapsed Time:')
print(end-start)
# Out:
# [('B', 'T'), ('G', 'F'), ('G', 'B'), ('F', 'S'), ('T', 'S')]
# Elapsed Time:
# 0.5657036304473877

# %% [markdown]
# ## PC Algorithm

# %%
PCest = ConstraintBasedEstimator(sample10)
start = time.time()
skel, seperating_sets = PCest.estimate_skeleton(significance_level=0.01)
pdag = PCest.skeleton_to_pdag(skel, seperating_sets)
PCmodel = PCest.pdag_to_dag(pdag)
end = time.time()

print("Elapsed Time: ", end-start, " sec")
print("Undirected edges: ", skel.edges())
print("PDAG edges:       ", pdag.edges())
print("DAG edges:        ", model.edges())
# Out:
# Elapsed Time:  0.45688557624816895  sec
# Undirected edges:  [('F', 'T'), ('F', 'S'), ('T', 'S')]
# PDAG edges:        [('F', 'T'), ('F', 'S'), ('T', 'F'), ('T', 'S'), ('S', 'F'), ('S', 'T')]
# DAG edges:         [('B', 'G'), ('B', 'T'), ('F', 'G'), ('F', 'S'), ('T', 'S')]

# %%
print('p(f|s=0,t=0)')
print(inference.query(['F'], evidence={'S': 0, 'T': 0}))
print('p(b|s=0,t=0)')
print(inference.query(['B'], evidence={'S': 0, 'T': 0}))
print('p(f|s=0,t=1)')
print(inference.query(['F'], evidence={'S': 0, 'T': 1}))
print('p(b|s=0,t=1)')
print(inference.query(['B'], evidence={'S': 0, 'T': 1}))
# Out:
# Finding Elimination Order: : 100%|██████████| 2/2 [00:00<00:00, 305.89it/s]
# Eliminating: B: 100%|██████████| 2/2 [00:00<00:00, 231.91it/s]
# Finding Elimination Order: : 100%|██████████| 2/2 [00:00<00:00, 906.48it/s]
# Eliminating: F: 100%|██████████| 2/2 [00:00<00:00, 265.89it/s]
# Finding Elimination Order: : 100%|██████████| 2/2 [00:00<00:00, 528.55it/s]
# Eliminating: B: 100%|██████████| 2/2 [00:00<00:00, 201.49it/s]
# Finding Elimination Order: : 100%|██████████| 2/2 [00:00<00:00, 358.69it/s]
# Eliminating: F: 100%|██████████| 2/2 [00:00<00:00, 203.16it/s]
# p(f|s=0,t=0)
# +------+----------+
# | F    |   phi(F) |
# +======+==========+
# | F(0) |   0.0495 |
# +------+----------+
# | F(1) |   0.9505 |
# +------+----------+
# p(b|s=0,t=0)
# +------+----------+
# | B    |   phi(B) |
# +======+==========+
# | B(0) |   0.4000 |
# +------+----------+
# | B(1) |   0.6000 |
# +------+----------+
# p(f|s=0,t=1)
# +------+----------+
# | F    |   phi(F) |
# +======+==========+
# | F(0) |   0.8288 |
# +------+----------+
# | F(1) |   0.1712 |
# +------+----------+
# p(b|s=0,t=1)
# +------+----------+
# | B    |   phi(B) |
# +======+==========+
# | B(0) |   0.0004 |
# +------+----------+
# | B(1) |   0.9996 |
# +------+----------+
